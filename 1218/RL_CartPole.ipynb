# %% [markdown]
# # ライブラリのインポート

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %% [markdown]
# # 動画に保存する関数

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def save_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)

    anim.save('RL-cartpole.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
# 学習に使う変数を整理
ENV = 'CartPole-v0'
# 状態をどれくらいの値で分割して離散値とするか
NUM_DIGITIZED = 6
# 報酬割引率
GAMMA = 0.99
# 学習率
ETA = 0.5
# 1試行（1エピソード）の最大ステップ数
MAX_STEP = 200
# 最大試行回数（エピソード数）
NUM_EPISODES = 500

# %%
# エージェントクラス
class Agent:

    # 初期化関数で行動数と行動の種類を受けとり，行動を決定するためのBrainクラスを生成する
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)

    # Q関数を更新
    def update_q_function(self, observation, action, reward, observation_next):
        self.brain.update_Q_table(observation, action, reward, observation_next)

    # 行動の決定
    def get_action(self, observation, step):
        return self.brain.decide_action(observation, step)


# エージェントが行う行動を与えられた状態によって判断する部分（強化学習を行う部分）
class Brain:

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        # Qテーブルを作成。行数は状態を分割数^（4変数）にデジタル変換した値、列数は行動数を示す
        self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIGITIZED**num_states, num_actions))


    # カート情報を離散化するための閾値を求める
    def bins(self, clip_min, clip_max, num):
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    # カートの情報を離散化する
    def digitize_state(self, observation):
        '''観測したobservation状態を、離散値に変換する'''
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIGITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIGITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIGITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIGITIZED))
        ]
        return sum([x * (NUM_DIGITIZED**i) for i, x in enumerate(digitized)])

    # QテーブルをQ学習により更新
    def update_Q_table(self, observation, action, reward, observation_next):
        Q = self.q_table
        state = self.digitize_state(observation)
        state_next = self.digitize_state(observation_next)
        Q[state, action] = Q[state, action] + ETA * (reward + GAMMA * np.nanmax(Q[state_next, :]) - Q[state, action])
        return Q
        


    # ε-greedy法で徐々に最適行動を行うようにする
    def decide_action(self, observation, episode):
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode+1))
        
        if epsilon < np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)
        return action

# %%
## CartPoleを実行する環境
class Environment:

    def __init__(self):
        self.env = gym.make(ENV)  # 実行する課題を設定
        num_states = self.env.observation_space.shape[0]  # 課題の状態を取得
        num_actions = self.env.action_space.n  # CartPoleの行動を取得
        self.agent = Agent(num_states, num_actions)  # 環境内で行動するAgentを生成

    ## 実行関数
    def run(self):

        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        is_episode_final = False  # 最終試行フラグ
        frames = []  # 動画用に画像を格納する変数

        # 全エピソードループ
        for i in range(NUM_EPISODES):
            # ほげほげ
            observation = self.env.reset()
            episode_reward = 0

            # 1エピソードループ
            for l in range(MAX_STEP):
                if is_episode_final is True:
                    # framesに各時刻の画像を追加していく
                    frames.append(self.env.render(mode='rgb_array'))
            # ほげほげ
                action = self.agent.get_action(observation, i)
                observation_next, reward_notuse, done, info_notuse = self.env.step(action)
                
                if done:
                    if l < 195:
                        reward = -1
                        self.complete_episodes = 0
                    else:
                        reward = 1
                        complete_episodes += 1
                else:
                    reward = 0
                
                episode_reward += reward
                
                self.agent.update_q_function(observation, action, reward, observation_next)
                
                observation = observation_next
                
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(i, l+1))
                    break
                    
            if is_episode_final is True:
                # 動画を保存と描画
                save_as_gif(frames)
                break

            if complete_episodes >= 10:
                print('10回連続成功')
                frames = []
                is_episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# 0 Episode: Finished after 10 time steps
# 1 Episode: Finished after 12 time steps
# 2 Episode: Finished after 56 time steps
# 3 Episode: Finished after 27 time steps
# 4 Episode: Finished after 18 time steps
# 5 Episode: Finished after 8 time steps
# 6 Episode: Finished after 12 time steps
# 7 Episode: Finished after 44 time steps
# 8 Episode: Finished after 11 time steps
# 9 Episode: Finished after 36 time steps
# 10 Episode: Finished after 11 time steps
# 11 Episode: Finished after 54 time steps
# 12 Episode: Finished after 16 time steps
# 13 Episode: Finished after 15 time steps
# 14 Episode: Finished after 11 time steps
# 15 Episode: Finished after 25 time steps
# 16 Episode: Finished after 9 time steps
# 17 Episode: Finished after 96 time steps
# 18 Episode: Finished after 17 time steps
# 19 Episode: Finished after 35 time steps
# 20 Episode: Finished after 55 time steps
# 21 Episode: Finished after 70 time steps
# 22 Episode: Finished after 78 time steps
# 23 Episode: Finished after 69 time steps
# 24 Episode: Finished after 115 time steps
# 25 Episode: Finished after 30 time steps
# 26 Episode: Finished after 19 time steps
# 27 Episode: Finished after 25 time steps
# 28 Episode: Finished after 69 time steps
# 29 Episode: Finished after 147 time steps
# 30 Episode: Finished after 200 time steps
# 31 Episode: Finished after 17 time steps
# 32 Episode: Finished after 158 time steps
# 33 Episode: Finished after 45 time steps
# 34 Episode: Finished after 14 time steps
# 35 Episode: Finished after 12 time steps
# 36 Episode: Finished after 16 time steps
# 37 Episode: Finished after 37 time steps
# 38 Episode: Finished after 113 time steps
# 39 Episode: Finished after 26 time steps
# 40 Episode: Finished after 105 time steps
# 41 Episode: Finished after 185 time steps
# 42 Episode: Finished after 73 time steps
# 43 Episode: Finished after 78 time steps
# 44 Episode: Finished after 74 time steps
# 45 Episode: Finished after 80 time steps
# 46 Episode: Finished after 25 time steps
# 47 Episode: Finished after 30 time steps
# 48 Episode: Finished after 34 time steps
# 49 Episode: Finished after 102 time steps
# 50 Episode: Finished after 33 time steps
# 51 Episode: Finished after 126 time steps
# 52 Episode: Finished after 44 time steps
# 53 Episode: Finished after 68 time steps
# 54 Episode: Finished after 94 time steps
# 55 Episode: Finished after 109 time steps
# 56 Episode: Finished after 96 time steps
# 57 Episode: Finished after 90 time steps
# 58 Episode: Finished after 41 time steps
# 59 Episode: Finished after 45 time steps
# 60 Episode: Finished after 132 time steps
# 61 Episode: Finished after 90 time steps
# 62 Episode: Finished after 84 time steps
# 63 Episode: Finished after 87 time steps
# 64 Episode: Finished after 114 time steps
# 65 Episode: Finished after 120 time steps
# 66 Episode: Finished after 93 time steps
# 67 Episode: Finished after 92 time steps
# 68 Episode: Finished after 66 time steps
# 69 Episode: Finished after 32 time steps
# 70 Episode: Finished after 77 time steps
# 71 Episode: Finished after 88 time steps
# 72 Episode: Finished after 66 time steps
# 73 Episode: Finished after 129 time steps
# 74 Episode: Finished after 160 time steps
# 75 Episode: Finished after 77 time steps
# 76 Episode: Finished after 76 time steps
# 77 Episode: Finished after 81 time steps
# 78 Episode: Finished after 84 time steps
# 79 Episode: Finished after 78 time steps
# 80 Episode: Finished after 114 time steps
# 81 Episode: Finished after 84 time steps
# 82 Episode: Finished after 134 time steps
# 83 Episode: Finished after 29 time steps
# 84 Episode: Finished after 39 time steps
# 85 Episode: Finished after 94 time steps
# 86 Episode: Finished after 79 time steps
# 87 Episode: Finished after 83 time steps
# 88 Episode: Finished after 200 time steps
# 89 Episode: Finished after 188 time steps
# 90 Episode: Finished after 106 time steps
# 91 Episode: Finished after 200 time steps
# 92 Episode: Finished after 89 time steps
# 93 Episode: Finished after 32 time steps
# 94 Episode: Finished after 87 time steps
# 95 Episode: Finished after 194 time steps
# 96 Episode: Finished after 21 time steps
# 97 Episode: Finished after 164 time steps
# 98 Episode: Finished after 21 time steps
# 99 Episode: Finished after 28 time steps
# 100 Episode: Finished after 172 time steps
# 101 Episode: Finished after 200 time steps
# 102 Episode: Finished after 105 time steps
# 103 Episode: Finished after 49 time steps
# 104 Episode: Finished after 94 time steps
# 105 Episode: Finished after 67 time steps
# 106 Episode: Finished after 170 time steps
# 107 Episode: Finished after 43 time steps
# 108 Episode: Finished after 163 time steps
# 109 Episode: Finished after 141 time steps
# 110 Episode: Finished after 114 time steps
# 111 Episode: Finished after 44 time steps
# 112 Episode: Finished after 133 time steps
# 113 Episode: Finished after 176 time steps
# 114 Episode: Finished after 123 time steps
# 115 Episode: Finished after 200 time steps
# 116 Episode: Finished after 175 time steps
# 117 Episode: Finished after 200 time steps
# 118 Episode: Finished after 200 time steps
# 119 Episode: Finished after 100 time steps
# 120 Episode: Finished after 110 time steps
# 121 Episode: Finished after 200 time steps
# 122 Episode: Finished after 200 time steps
# 123 Episode: Finished after 115 time steps
# 124 Episode: Finished after 53 time steps
# 125 Episode: Finished after 200 time steps
# 10回連続成功
# 126 Episode: Finished after 115 time steps
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/JSAnimation/html_writer.py in grab_frame(self, **savefig_kwargs)
#     287             f = InMemory()
# --> 288             self.fig.savefig(f, format=self.frame_format,
#     289                              dpi=self.dpi, **savefig_kwargs)
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     642         else:
# --> 643             im, l, b, trans = self.make_image(
#     644                 renderer, renderer.get_image_magnification())
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     927                 else self.figure.bbox)
# --> 928         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     929                                 magnification, unsampled=unsampled)
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     549                 if A.shape[2] == 3:
# --> 550                     A = _rgb_to_rgba(A)
#     551                 alpha = self._get_scalar_alpha()
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/image.py in _rgb_to_rgba(A)
#     206     rgba = np.zeros((A.shape[0], A.shape[1], 4), dtype=A.dtype)
# --> 207     rgba[:, :, :3] = A
#     208     if rgba.dtype == np.uint8:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-135fd70ab5ea> in <module>
#       1 # main
#       2 cartpole_env = Environment()
# ----> 3 cartpole_env.run()
#
# <ipython-input-5-1476866eafe7> in run(self)
#      52             if is_episode_final is True:
#      53                 # 動画を保存と描画
# ---> 54                 save_as_gif(frames)
#      55                 break
#      56
#
# <ipython-input-2-afd81d25a2e4> in save_as_gif(frames)
#      14
#      15     anim.save('RL-cartpole.mp4')
# ---> 16     display(display_animation(anim, default_mode='loop'))
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/JSAnimation/IPython_display.py in display_animation(anim, **kwargs)
#      84     """Display the animation with an IPython HTML object"""
#      85     from IPython.display import HTML
# ---> 86     return HTML(anim_to_html(anim, **kwargs))
#      87
#      88
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/JSAnimation/IPython_display.py in anim_to_html(anim, fps, embed_frames, default_mode)
#      72         #with tempfile.NamedTemporaryFile(suffix='.html') as f:
#      73         with _NameOnlyTemporaryFile(suffix='.html') as f:
# ---> 74             anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                                  embed_frames=embed_frames,
#      76                                                  default_mode=default_mode))
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     516         # Call run here now that all frame grabbing is done. All temp files
#     517         # are available to be assembled.
# --> 518         self._run()
#     519         MovieWriter.finish(self)  # Will call clean-up
#     520
#
# ~/.local/share/virtualenvs/ai_hasegawa-U3IJz7-M/lib/python3.8/site-packages/JSAnimation/html_writer.py in _run(self)
#     321             of.write(JS_INCLUDE)
#     322             of.write(DISPLAY_TEMPLATE.format(id=self.new_id(),
# --> 323                                              Nframes=len(self._temp_names),
#     324                                              fill_frames=fill_frames,
#     325                                              interval=interval,
#
# AttributeError: 'HTMLWriter' object has no attribute '_temp_names'
